# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.drop(3,inplace=True)

# %%
df.set_index('Name',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
d={
    'key1':[3,4,5,6,7],
    'key2':[5,6,7,8,9],
    'key3':[4,5,6,6,7]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     6
# 4     7     9     7

# %%
df.dropna()
# Out:
#                                                   Name  Survived  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 5                              McCarthy, Mr. Timothy J         0       1
# 9                      Sandstrom, Miss. Marguerite Rut         1       3
# 10                            Bonnell, Miss. Elizabeth         1       1
# 20                               Beesley, Mr. Lawrence         1       2
# ..                                                 ...       ...     ...
# 870   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         1       1
# 871                           Carlsson, Mr. Frans Olof         0       1
# 878      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1       1
# 886                       Graham, Miss. Margaret Edith         1       1
# 888                              Behr, Mr. Karl Howell         1       1
#
#         Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
df.dropna(axis=1)
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex  SibSp  Parch            Ticket     Fare
# ...

# %%
df.fillna('empty value')
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex          Age  SibSp  Parch            Ticket     Fare  \
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g=df.groupby(by='Survived')

# %%
g.sum()
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1=df.groupby('Pclass')

# %%
g1.sum()
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T
# Out:
# C:\Users\kmrsh\AppData\Local\Temp\ipykernel_4872\2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
df5=df[['Name','Survived','Pclass']][0:5]

# %%
df6=df[['Name','Survived','Pclass']][0:5]

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df7=pd.concat([df5,df6],axis=1)

# %%
df7.fillna('not a number')
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
data1=pd.DataFrame({'key1':[1,2,3,4,5,6],
                   'key2':[4,5,6,7,8,9],
                   'key3':[3,4,5,6,6,10]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     6
# 5     6     9    10

# %%
data2=pd.DataFrame({'key1':[12,23,3,43,5,6],
                   'key4':[42,52,63,7,8,9],
                   'key5':[3,4,5,63,6,10]})

# %%
data2
# Out:
#    key1  key4  key5
# 0    12    42     3
# 1    23    52     4
# 2     3    63     5
# 3    43     7    63
# 4     5     8     6
# 5     6     9    10

# %%
pd.merge(data1,data2,how='outer') #it is merging based on same column from both side.
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0   NaN   NaN
# 1     2   5.0   4.0   NaN   NaN
# 2     3   6.0   5.0  63.0   5.0
# 3     4   7.0   6.0   NaN   NaN
# 4     5   8.0   6.0   8.0   6.0
# 5     6   9.0  10.0   9.0  10.0
# 6    12   NaN   NaN  42.0   3.0
# 7    23   NaN   NaN  52.0   4.0
# 8    43   NaN   NaN   7.0  63.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3      12    42     3
# 1        1     4     3      23    52     4
# 2        1     4     3       3    63     5
# 3        1     4     3      43     7    63
# 4        1     4     3       5     8     6
# 5        1     4     3       6     9    10
# 6        2     5     4      12    42     3
# 7        2     5     4      23    52     4
# 8        2     5     4       3    63     5
# 9        2     5     4      43     7    63
# 10       2     5     4       5     8     6
# 11       2     5     4       6     9    10
# 12       3     6     5      12    42     3
# 13       3     6     5      23    52     4
# 14       3     6     5       3    63     5
# 15       3     6     5      43     7    63
# 16       3     6     5       5     8     6
# 17       3     6     5       6     9    10
# 18       4     7     6      12    42     3
# 19       4     7     6      23    52     4
# 20       4     7     6       3    63     5
# ...

# %%
pd.merge(data1,data2,how='inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     3     6     5    63     5
# 1     5     8     6     8     6
# 2     6     9    10     9    10

# %%
data1.merge(data2,on='key1',suffixes=('_left', '_right'))
# Out:
#    key1  key2  key3  key4  key5
# 0     3     6     5    63     5
# 1     5     8     6     8     6
# 2     6     9    10     9    10

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     3     6     5
# 3     4     7     6
# 4     5     8     6
# 5     6     9    10

# %%
data2
# Out:
#    key1  key4  key5
# 0    12    42     3
# 1    23    52     4
# 2     3    63     5
# 3    43     7    63
# 4     5     8     6
# 5     6     9    10

# %%
data1=pd.DataFrame({'key11':[1,2,3,4,5,6],
                   'key22':[4,5,6,7,8,9],
                   'key33':[3,4,5,6,6,10]},
                  index=['a','b','c','d','e','g'])

# %%
data2=pd.DataFrame({'key1':[12,23,3,43,5,6],
                   'key4':[42,52,63,7,8,9],
                   'key5':[3,4,5,63,6,10]},
                        index=['e','f','g','h','i','j'])

# %%
data1.join(data2,how='inner') #join is used to map on indexes
# Out:
#    key11  key22  key33  key1  key4  key5
# e      5      8      6    12    42     3
# g      6      9     10     3    63     5

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['Fare_INR']=df['Fare'].apply(lambda x:x*80)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#    Fare_INR
# 0   580.000
# 1  5702.664
# 2   634.000
# 3   644.000
# 4   676.664

# %%
df['Name_len']=df['Name'].apply(len)

# %%
def cat_fare(x):
    if x<10:
        return 'cheap'
    elif x>=10 and x<20:
        return 'mid'
    else:
        return 'high'

# %%
df['category_fare']=df['Fare'].apply(cat_fare)
