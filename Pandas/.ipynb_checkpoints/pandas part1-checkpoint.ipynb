# %%
import pandas as pd

# %%
df=pd.read_csv('services.csv',index_col='id')

# %%
df.head(2)
# Out:
#     location_id  program_id accepted_payments alternate_name  \
# id
# 1             1         NaN               NaN            NaN
# 2             2         NaN               NaN            NaN
#
#                    application_process  \
# id
# 1           Walk in or apply by phone.
# 2   Apply by phone for an appointment.
#
#                                              audience  \
# id
# 1   Older adults age 55 or over, ethnic minorities...
# 2        Residents of San Mateo County age 55 or over
#
#                                           description  \
# id
# 1   A walk-in center for older adults that provide...
# 2   Provides training and job placement to eligibl...
#
#                                           eligibility email  \
# id
# 1   Age 55 or over for most programs, age 60 or ov...   NaN
# 2   Age 55 or over, county resident and willing an...   NaN
#
#                                                  fees  ...  \
# id                                                     ...
# 1   $2.50 suggested donation for lunch for age 60 ...  ...
# 2   None. Donations requested of clients who can a...  ...
#
#    interpretation_services                                           keywords  \
# id
# 1                      NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 2                      NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
#
#    languages                              name required_documents  \
# id
# 1        NaN   Fair Oaks Adult Activity Center                NaN
# 2        NaN  Second Career Employment Program                NaN
#
#        service_areas  status wait_time website taxonomy_ids
# id
# 1              Colma  active  No wait.     NaN          NaN
# 2   San Mateo County  active   Varies.     NaN          NaN
#
# [2 rows x 21 columns]

# %%
df.tail()
# Out:
#     location_id  program_id         accepted_payments         alternate_name  \
# id
# 19           19         NaN                       NaN                    NaN
# 20           20         NaN                       NaN                    NaN
# 21           21         NaN                       NaN                    NaN
# 22           22         NaN  Cash, Check, Credit Card  Fotos para pasaportes
# 23           22         NaN                       NaN                    NaN
#
#                                application_process  \
# id
# 19  Call for screening appointment (650-347-3648).
# 20                                        Walk in.
# 21                 By phone during business hours.
# 22               Walk in or apply by phone or mail
# 23               Walk in or apply by phone or mail
#
#                                              audience  \
# id
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  Profit and nonprofit businesses, the public, m...
# 23  Second service and nonprofit businesses, the p...
#
#                                           description  \
# id
# 19  Provides free medical and dental care to those...
# 20              no unrequired fields for this service
# 21                                just a test service
# 22  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...
# 23  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                                         eligibility                  email  \
# id
# 19  Low-income person without access to health care                    NaN
# 20                                              NaN                    NaN
# 21                                              NaN                    NaN
# 22                                             None  passports@example.org
# 23                                             None                    NaN
#
#                                                  fees  ...  \
# id                                                     ...
# 19                                              None.  ...
# 20                                                NaN  ...
# 21                                                NaN  ...
# 22  None, except for permits and photocopying. Cas...  ...
# 23  None, except for permits and photocopying. Cas...  ...
#
#                               interpretation_services  \
# id
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  We offer 3-way interpretation services over th...
# 23                                                NaN
#
#                                              keywords languages  \
# id
# 19  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 20                                                NaN       NaN
# 21                                                NaN       NaN
# 22                                    Salud, Medicina   Spanish
# 23         Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                                name                        required_documents  \
# id
# 19    San Mateo Free Medical Clinic                                       NaN
# 20        Service with blank fields                                       NaN
# 21  Service for Admin Test Location                                       NaN
# 22                  Passport Photos  Government-issued picture identification
# 23             Example Service Name                                       NaN
#
#                        service_areas    status            wait_time  \
# id
# 19               Belmont, Burlingame    active              Varies.
# 20                               NaN   defunct                  NaN
# 21                  San Mateo County  inactive                  NaN
# 22  Alameda County, San Mateo County    active  No wait to 2 weeks.
# 23  San Mateo County, Alameda County    active   No wait to 2 weeks
#
#                    website                              taxonomy_ids
# id
# 19                     NaN                                       NaN
# 20                     NaN                                       NaN
# 21                     NaN                                       NaN
# 22  http://www.example.com  105, 108, 108-05, 108-05-01, 111, 111-05
# 23  http://www.example.com                                       NaN
#
# [5 rows x 21 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df.columns)
# Out:
# ['location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['status'].value_counts()
# Out:
# active      21
# defunct      1
# inactive     1
# Name: status, dtype: int64

# %%
type(df['status'])
# Out:
# pandas.core.series.Series

# %%
type(df[['status']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['location_id', 'program_id', 'accepted_payments', 'alternate_name',
#        'application_process', 'audience', 'description', 'eligibility',
#        'email', 'fees', 'funding_sources', 'interpretation_services',
#        'keywords', 'languages', 'name', 'required_documents', 'service_areas',
#        'status', 'wait_time', 'website', 'taxonomy_ids'],
#       dtype='object')

# %%
df[['email','name']]
# Out:
#                     email                                  name
# id
# 1                     NaN       Fair Oaks Adult Activity Center
# 2                     NaN      Second Career Employment Program
# 3                     NaN                Senior Peer Counseling
# 4                     NaN              Family Visitation Center
# 5                     NaN     Economic Self-Sufficiency Program
# 6                     NaN  Little House Recreational Activities
# 7                     NaN      Rosener House Adult Day Services
# 8                     NaN        Meals on Wheels - South County
# 9                     NaN                      Fair Oaks Branch
# 10                    NaN                          Main Library
# 11                    NaN                       Schaberg Branch
# 12                    NaN                          Project Read
# 13                    NaN                 Redwood Shores Branch
# 14                    NaN                    Redwood City Corps
# 15                    NaN           Adult Rehabilitation Center
# 16                    NaN                       Sunnyvale Corps
# 17                    NaN     South San Francisco Citadel Corps
# 18                    NaN                         Project Smile
# 19                    NaN         San Mateo Free Medical Clinic
# 20                    NaN             Service with blank fields
# 21                    NaN       Service for Admin Test Location
# 22  passports@example.org                       Passport Photos
# 23                    NaN                  Example Service Name

# %%
df.dtypes
# Out:
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df1=pd.read_excel('LUSID Excel - Setting up your market data.xlsx')

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1[['Unnamed: 0','Unnamed: 1']]
# Out:
#     Unnamed: 0  Unnamed: 1
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
url_data=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 1

# %%
df3=url_data[0]

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df3.to_csv('players_data.csv',index=False)
