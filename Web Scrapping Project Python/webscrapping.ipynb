# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen 
import logging

# %%
flipcart_url="https://www.flipkart.com/search?q=" + "iphone12pro"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone12pro'

# %%
urlclient=urlopen(flipcart_url)

# %%
urlclient

# %%
flipcart_page=urlclient.read()

# %%
flipcart_html=bs(flipcart_page,'html.parser')

# %%
box=flipcart_html.find_all('div',{'class':"_2kHMtA"})

# %%
len(box)
# Out:
# 24

# %%
base_url='https://www.flipkart.com'

# %%
url=base_url+ box[0].a['href']

# %%
print(url)
# Out:
# https://www.flipkart.com/apple-iphone-12-pro-silver-512-gb/p/itm0ccf9fc219a71?pid=MOBFWBYZ5UY6ZBVA&lid=LSTMOBFWBYZ5UY6ZBVASXARTV&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=0fe7d617-22ff-419e-8c7c-23cfb167f8d9.MOBFWBYZ5UY6ZBVA.SEARCH&ppt=None&ppn=None&ssid=ztf3dw730g0000001677225060067&qH=712933e6bd68e7b9

# %%
review_page=requests.get(url)

# %%
review_page_html=bs(review_page.text,'html.parser')

# %%
review_box=review_page_html.find_all('div',{'class':"col _2wzgFH"})

# %%
review_box[0].div.div.text
# Out:
# '5'

# %%
review_box[0].find_all('div',{'class':"row _3n8db9"})
# Out:
# [<div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Vinit Kar</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-4cde68ab-62b5-4c7f-bc3b-f3f45fc36b09"><span>Certified Buyer</span><span>, Mumbai</span></p><div></div><p class="_2sc7ZR">Jul, 2021</p></div><div class="_1e9_Zu"><div class="row"><div class="_27aTsS"><div class="_1LmwT9"><svg class="skCrcq" height="15" width="20" xmlns="http://www.w3.org/2000/svg"><path class="_1LIt4y" d="M9.58.006c-.41.043-.794.32-1.01.728-.277.557-2.334 4.693-2.74 5.1-.41.407-.944.6-1.544.6v8.572h7.5c.45 0 .835-.28 1.007-.665 0 0 2.207-6.234 2.207-6.834 0-.6-.47-1.072-1.07-1.072h-3.216c-.6 0-1.07-.535-1.07-1.07 0-.537.835-3.387 1.006-3.944.17-.557-.107-1.157-.664-1.35-.15-.043-.257-.086-.407-.064zM0 6.434v8.572h2.143V
# ...

# %%
review_box[0].div.p.text
# Out:
# 'Best in the market!'

# %%
review_box[0].find_all('div')[2].div.text
# Out:
# 'I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!READ MORE'

# %%
review_page_html
# Out:
# <!DOCTYPE html>
# ...

# %%
product_req=requests.get(base_url)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_html=bs(product_req.text,'html.parser')

# %%
for i in box:
    print(base_url+i.a['href'])
    review_page=base_url+i.a['href']
    review_page=requests.get(url)
    
    review_page_html=bs(review_page.text,'html.parser')
    
    review_boxes=review_page_html.find_all('div',{'class':"col _2wzgFH"})
    for review_box in review_boxes:
        
        print(review_box.div.div.text)
        print(review_box.div.p.text)
        print(review_box.find_all('div')[2].div.div.div.text)
        print(review_box.find_all('div',{'class':"row _3n8db9"})[0].p.text)
        print(review_box.find_all('div',{'class':"row _3n8db9"})[0].find_all('p')[1].find_all('span')[1].text)
        print(review_box.find_all('div',{'class':"row _3n8db9"})[0].find_all('p')[2].text)
# Out:
# https://www.flipkart.com/apple-iphone-12-pro-silver-512-gb/p/itm0ccf9fc219a71?pid=MOBFWBYZ5UY6ZBVA&lid=LSTMOBFWBYZ5UY6ZBVASXARTV&marketplace=FLIPKART&q=iphone12pro&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=0fe7d617-22ff-419e-8c7c-23cfb167f8d9.MOBFWBYZ5UY6ZBVA.SEARCH&ppt=None&ppn=None&ssid=ztf3dw730g0000001677225060067&qH=712933e6bd68e7b9
# 5
# Best in the market!
# I have been using iPhones for years, but the fast charging and battery on this one is brilliant. Like i always say, iPhone is more of a jewellery than a phone. But this one has some power-packed features and an awesome camera. So if you can afford it, buy it!
# Vinit Kar
# , Mumbai
# Jul, 2021
# 5
# Highly recommended
# ...
